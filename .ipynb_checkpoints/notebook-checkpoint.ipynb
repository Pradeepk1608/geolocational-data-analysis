# %%
# Import requirements
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt 
from matplotlib.colors import ListedColormap
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import json
import requests
import folium
import geopy

# %%
data = pd.read_csv('food_coded.csv')
print(type(data))
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 0                         9.0  ...   1.0     1.0          1            1165.0
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 3                         2.0  ...   1.0     2.0          5             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  \
# 0              345   car racing           5         1             1315
# 1              690  Basketball            4         2              900
# 2              500         none           5         1              900
# 3              690          NaN           3         1             1315
# 4              500     Softball           4         2              760
#
#                      weight
# 0                       187
# 1                       155
# 2  I'm not answering this.
# 3             Not sure, 240
# 4                       190
#
# [5 rows x 61 columns]

# %%
# to_drop = ['weight', 'soup']
# data.drop(columns = to_drop, inplace = True)

df = data[["cook",  "eating_out", "employment", "ethnic_food", 
           "exercise", "fruit_day","income", "on_off_campus",
            "pay_meal_out", "sports", 'veggies_day']]
print(df.shape)
df.head()
# Out:
# (125, 11)
#    cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0   2.0           3         3.0            1       1.0          5     5.0
# 1   3.0           2         2.0            4       1.0          4     4.0
# 2   1.0           2         3.0            5       2.0          5     6.0
# 3   2.0           2         3.0            5       3.0          4     6.0
# 4   1.0           2         2.0            4       1.0          4     6.0
#
#    on_off_campus  pay_meal_out  sports  veggies_day
# 0            1.0             2     1.0            5
# 1            1.0             4     1.0            4
# 2            2.0             3     2.0            5
# 3            1.0             2     2.0            3
# 4            1.0             4     1.0            4

# %%
df.loc[122].head()
# Out:
# cook           3.0
# eating_out     3.0
# employment     3.0
# ethnic_food    5.0
# exercise       2.0
# Name: 122, dtype: float64

# %%
df.iloc[122].head()
# Out:
# cook           3.0
# eating_out     3.0
# employment     3.0
# ethnic_food    5.0
# exercise       2.0
# Name: 122, dtype: float64

# %%
df.loc[56:, 'income'].head()
# Out:
# 56    6.0
# 57    5.0
# 58    5.0
# 59    6.0
# 60    6.0
# Name: income, dtype: float64

# %%
to_use= ["cook",  "eating_out", "employment", "ethnic_food", 
           "exercise", "fruit_day","income", "on_off_campus",
            "pay_meal_out", "sports", 'veggies_day']

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=20)  
sns.boxplot(data=df)
# Out:
# <AxesSubplot: >

# %%
# From the above box plot we can say that the main factors to consider are ethnic_foods, income and veggies_day 
# because they have distributed range of values and can be used to cluster students in groups

# %%
x = list(range(0,df.shape[0]))
fig, axs = plt.subplots(3, 1)

axs[0].scatter(x, df["income"], c = "y", s = 15)
axs[1].scatter(x, df["ethnic_food"], c = "g", s = 15)
axs[2].scatter(x, df["veggies_day"], c = "m", s = 15)

# %% [markdown]
# <h2>On the basis of income</h2>

# %%
df['income'] = df['income'].replace(np.nan, 0)
df_in = pd.DataFrame(df["income"])
# Out:
# C:\Users\pmeen\AppData\Local\Temp\ipykernel_18888\927746093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['income'] = df['income'].replace(np.nan, 0)

# %%
x = np.array(range(0, 125))
df_in = df_in.set_index(x)
df_income = []
for i in range(125):
    df_income.append([i, float(df_in.loc[i])])
df_income = np.array(df_income)

# %%
scaler = MinMaxScaler()
df_main_income = scaler.fit_transform(df_income)

# %%
# optimal value for K using elbow method
def calculate_WSS(points, kmax):
  sse = []
  for k in range(1, kmax+1):
    kmeans = KMeans(n_clusters = k, n_init=10).fit(points)
    centroids = kmeans.cluster_centers_
    pred_clusters = kmeans.predict(points)
    curr_sse = 0
    
    # calculate square of Euclidean distance of each point from its cluster center and add to current WSS
    for i in range(len(points)):
      curr_center = centroids[pred_clusters[i]]
      curr_sse += (points[i, 0] - curr_center[0]) ** 2 + (points[i, 1] - curr_center[1]) ** 2
      
    sse.append(curr_sse)
  return sse

# %%
k_guess = 10
a = calculate_WSS(df_main_income, k_guess)
k = list(range(1, k_guess+1))
plt.plot(k, a)
plt.show()

print("Optimal K = 3")
# Out:
# Optimal K = 3

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=10, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(df_main_income)
plt.scatter(df_main_income[:,0], df_main_income[:,1], c=kmeans.labels_.astype(float))
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker = "d", s=50, c='red')
plt.show()

# %% [markdown]
# <h2>Clustering On the basis of Ethnic_food</h2>

# %%
df["ethnic_food"] = df["ethnic_food"].replace(np.nan, 0)
df_ef = pd.DataFrame(df["ethnic_food"])
df_ef = df_ef.set_index(x)
# Out:
# C:\Users\pmeen\AppData\Local\Temp\ipykernel_18888\3508894002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ethnic_food"] = df["ethnic_food"].replace(np.nan, 0)

# %%
df_ethfood = []
for i in range(125):
    df_ethfood.append([i, float(df_ef.loc[i])])
df_ethfood = np.array(df_ethfood)

# %%
df_main_ethfood = scaler.fit_transform(df_ethfood)

# %%
k_guess = 10
a = calculate_WSS(df_main_ethfood, k_guess)
k = list(range(1, k_guess+1))
plt.plot(k, a)
plt.show()

print("Optimal K = 4")
# Out:
# Optimal K = 4

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=10, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(df_main_ethfood)
plt.scatter(df_main_ethfood[:,0], df_main_ethfood[:,1], c=kmeans.labels_.astype(float))
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker = "d", s=50, c='red')
plt.show()

# %% [markdown]
# <h2>Clustering On the basis of veggies_day</h2>

# %%
df["veggies_day"] = df["veggies_day"].replace(np.nan, 0)
df_vd = pd.DataFrame(df["veggies_day"])
df_vd = df_vd.set_index(x)
# Out:
# C:\Users\pmeen\AppData\Local\Temp\ipykernel_18888\456778960.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["veggies_day"] = df["veggies_day"].replace(np.nan, 0)

# %%
df_vegday = []
for i in range(125):
    df_vegday.append([i, float(df_vd.loc[i])])
df_vegday = np.array(df_vegday)

# %%
df_main_vegday = scaler.fit_transform(df_vegday)

# %%
k_guess = 10
a = calculate_WSS(df_main_vegday, k_guess)
k = list(range(1, k_guess+1))
plt.plot(k, a)
plt.show()

print("Optimal K = 4")
# Out:
# Optimal K = 4

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=10, n_init=10, random_state=1)
pred_y = kmeans.fit_predict(df_main_vegday)
plt.scatter(df_main_vegday[:,0], df_main_vegday[:,1], c=kmeans.labels_.astype(float))
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker = "d", s=50, c='red')
plt.show()

# %%
CLIENT_ID = 'XIIM5W1A0NKAFDSEAUJ34FHU0GHVJ5FUESJPXXPZ1PJEGKB0' 
CLIENT_SECRET = '0D52FZGNWAS5FLJ1Y5QOFYPAGM12CWG13NS4O2OEVSPT4YIE' 
VERSION = '20200316'
LIMIT = 10000
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    19.08157715, 72.88662753964906,
    30000, 
    LIMIT)
data = requests.get(url).json()

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '661093f584d31e56883d180d'},
#  'response': {'queryRefinements': {'target': {'type': 'path',
#     'url': '/venue/explore',
#     'params': {'ll': '19.081577,72.886628', 'radius': '30000'}},
#    'refinements': [{'query': 'Food'},
#     {'query': 'Nightlife'},
#     {'query': 'Coffee'},
#     {'query': 'Shops'},
#     {'query': 'Arts'},
#     {'query': 'Outdoors'}]},
#   'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Mumbai',
#   'headerFullLocation': 'Mumbai',
#   'headerLocationGranularity': 'city',
#   'totalResults': 171,
#   'suggestedBounds': {'ne': {'lat': 19.35157742000027,
#     'lng': 73.17179233098825},
#    'sw': {'lat': 18.81157687999973, 'lng': 72.60146274830986}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54a3a602498e6d5ac992f927',
#        'name': 'JW Marriott Mumbai Sahar',
#        'location': {'address': 'IA Project Road, Chhatrapati Shivaji International Airport, Andheri',
#         'lat': 19.102502,
#         'lng': 72.8782358,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.102502,
#           'lng': 72.8782358}],
#         'distance': 2490,
#         'postalCode': '400099',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['IA Project Road, Chhatrapati Shivaji International Airport, Andheri',
#          'Mumbai 400099',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'categoryCode': 19014,
#          'mapIcon': 'fsq-lodging',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '418953263'},
#        'createdAt': 1420011010},
#       'photo': {'id': '65310334cc33ec55491c5eea',
#        'createdAt': 1697710900,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/5665606_w8AruerI5qcxoIgU_hno8O_vdobbF081eborFbDqzCc.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-54a3a602498e6d5ac992f927-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a21b1cea4236243c9628ad2',
#        'name': 'Hitchki',
#        'location': {'address': 'FIFC',
#         'crossStreet': 'Bandra Kurla Complex, BKC',
#         'lat': 19.069729972809867,
#         'lng': 72.86976115276019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.069729972809867,
#           'lng': 72.86976115276019}],
#         'distance': 2210,
#         'postalCode': '400051',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['FIFC (Bandra Kurla Complex, BKC)',
#          'Mumbai 400051',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'categoryCode': 13003,
#          'mapIcon': 'fsq-bar',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1512157646},
#       'photo': {'id': '610a697d06450766fb84dee6',
#        'createdAt': 1628072317,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/4048110_KP9wINx95ITkmPAVbz6wCLkL0xT0XE0ZZDKsuUU18gM.jpg',
#        'width': 1789,
#        'height': 1440,
#        'visibility': 'public'},
#       'referralId': 'e-0-5a21b1cea4236243c9628ad2-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '546f25c5498e2d4d056ad6eb',
#        'name': 'Starbucks',
#        'location': {'address': 'The Capital',
#         'lat': 19.063456936971313,
#         'lng': 72.86157639300012,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.063456936971313,
#           'lng': 72.86157639300012}],
#         'distance': 3318,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['The Capital', 'Mumbai', 'Mahārāshtra', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'categoryCode': 13035,
#          'mapIcon': 'fsq-coffee',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1416570309},
#       'photo': {'id': '5fc63feb5ae69d3de3909947',
#        'createdAt': 1606828011,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/3775888_jccbgErinMgtHlsgCFQdge-UjSPd8Abnm-yFXwh_14M.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-546f25c5498e2d4d056ad6eb-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54a3b679498ef4dcbbf3ce69',
#        'name': 'J W Cafe',
#        'location': {'address': 'JW Marriott Mumbai Sahara',
#         'crossStreet': 'IA Project Road',
#         'lat': 19.103211778505766,
#         'lng': 72.87750391468353,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.103211778505766,
#           'lng': 72.87750391468353}],
#         'distance': 2592,
#         'postalCode': '400069',
#         'cc': 'IN',
#         'neighborhood': 'Airport',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['JW Marriott Mumbai Sahara (IA Project Road)',
#          'Mumbai 400069',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4d4b7105d754a06374d81259',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'categoryCode': 13065,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1420015225},
#       'photo': {'id': '5d79ced02b61ba000733f458',
#        'createdAt': 1568263888,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/63477693_6gdQi6nZA_YkD2YRQzraTM6AoxU4nFIJlD_FsoKY1Eo.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-54a3b679498ef4dcbbf3ce69-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587d8f964a52008a422e3',
#        'name': 'Guru Kripa',
#        'location': {'address': 'Guru Kripa Building, Near SIES College',
#         'crossStreet': 'Rd No 24',
#         'lat': 19.042954612559253,
#         'lng': 72.86179617563526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.042954612559253,
#           'lng': 72.86179617563526}],
#         'distance': 5030,
#         'postalCode': '400022',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Guru Kripa Building, Near SIES College (Rd No 24)',
#          'Mumbai 400022',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'categoryCode': 13199,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1258653656},
#       'photo': {'id': '504c914fe4b0369116e22552',
#        'createdAt': 1347195215,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/LLJ_16ESwON753MoDxc-tONaoeWqWew0PfxQreb8lTM.jpg',
#        'width': 720,
#        'height': 406,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587d8f964a52008a422e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5275159f11d265069773cd85',
#        'name': 'Starbucks',
#        'location': {'address': '15th Road, Red Chillies Building',
#         'crossStreet': 'Ramakrishna Mission Road, South Avenue, Santacruz ',
#         'lat': 19.075523243262623,
#         'lng': 72.8317448378628,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.075523243262623,
#           'lng': 72.8317448378628}],
#         'distance': 5813,
#         'postalCode': '4000052',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['15th Road, Red Chillies Building (Ramakrishna Mission Road, South Avenue, Santacruz )',
#          'Santacruz West 4000052',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'categoryCode': 13035,
#          'mapIcon': 'fsq-coffee',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1383404959},
#       'photo': {'id': '64a416f1981b054b8b4ea6cf',
#        'createdAt': 1688475377,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/108182_WXXJCAVONz37c1uNbwUaj6GtcbtiDoV3S7HovI-Kt1k.jpg',
#        'width': 1080,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-5275159f11d265069773cd85-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f927a04e4b020d1a28662c8',
#        'name': 'Indigo Deli',
#        'location': {'address': 'Pali Hill',
#         'crossStreet': 'Bandra',
#         'lat': 19.06171028998035,
#         'lng': 72.82997150211034,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.06171028998035,
#           'lng': 72.82997150211034}],
#         'distance': 6357,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Pali Hill (Bandra)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli',
#          'pluralName': 'Delis',
#          'shortName': 'Deli',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'categoryCode': 13039,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1334999556},
#       'photo': {'id': '51cd05d5498ef42909ebc152',
#        'createdAt': 1372390869,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/169141_dqZzn8U4DsmhasfRayBNPZk9tHw79G_lSAjVrgTS_NE.jpg',
#        'width': 720,
#        'height': 960,
#        'visibility': 'public'},
#       'referralId': 'e-0-4f927a04e4b020d1a28662c8-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcfe10f046076b0e02e6f71',
#        'name': 'Prithvi Theatre',
#        'location': {'address': 'Church Road',
#         'crossStreet': 'Juhu',
#         'lat': 19.106156977247707,
#         'lng': 72.82580993416029,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.106156977247707,
#           'lng': 72.82580993416029}],
#         'distance': 6958,
#         'postalCode': '400049',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Church Road (Juhu)',
#          'Mumbai 400049',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'categoryCode': 10043,
#          'mapIcon': 'fsq-arts-entertainment',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1271914767},
#       'photo': {'id': '51e56003498eded90c641d02',
#        'createdAt': 1373986819,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/60576626_8Ts8UHYs1_3qi0iRSRYDCCiRL66ZoASVCjFEsJ32MWE.jpg',
#        'width': 720,
#        'height': 960,
#        'visibility': 'public'},
#       'referralId': 'e-0-4bcfe10f046076b0e02e6f71-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5496e94e498e349305d81639',
#        'name': 'Bombay Salad Co.',
#        'location': {'address': 'Rita Apartment, 16th road, Lane next to Mini Punjab',
#         'crossStreet': 'Opposite syndicate bank',
#         'lat': 19.064715341256164,
#         'lng': 72.83091998224552,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.064715341256164,
#           'lng': 72.83091998224552}],
#         'distance': 6154,
#         'postalCode': '400050',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Rita Apartment, 16th road, Lane next to Mini Punjab (Opposite syndicate bank)',
#          'Mumbai 400050',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Restaurant',
#          'pluralName': 'Salad Restaurants',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'categoryCode': 13332,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1419176270},
#       'photo': {'id': '56c8466ecd109e9ba24c1c3c',
#        'createdAt': 1455965806,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/86018170_MNAFYwZU5IvTICGi7DRa50W-irvfpVjP2tsoMMSgB2g.jpg',
#        'width': 960,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-5496e94e498e349305d81639-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '573f159b498ee6b4bb61bd71',
#        'name': 'Bastian',
#        'location': {'address': 'Neelkamal',
#         'crossStreet': 'Waterfield Road, Bandra',
#         'lat': 19.0635656703907,
#         'lng': 72.83480660265644,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.0635656703907,
#           'lng': 72.83480660265644}],
#         'distance': 5808,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Neelkamal (Waterfield Road, Bandra)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'categoryCode': 13338,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1463752091},
#       'photo': {'id': '5b800ed22f97ec002c714a3a',
#        'createdAt': 1535119058,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/138616_CM8-434dcVtwSoTr1FM0hBf5U87ICbrJo_EtK9_vQYw.jpg',
#        'width': 1425,
#        'height': 1900,
#        'visibility': 'public'},
#       'referralId': 'e-0-573f159b498ee6b4bb61bd71-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587e2f964a52095a522e3',
#        'name': 'Merwans Cake shop',
#        'location': {'address': 'Near Andheri Station, SV Road',
#         'crossStreet': 'Andheri West',
#         'lat': 19.119300215885474,
#         'lng': 72.84541776016009,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.119300215885474,
#           'lng': 72.84541776016009}],
#         'distance': 6035,
#         'postalCode': '400 058',
#         'cc': 'IN',
#         'neighborhood': 'Andheri West',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Near Andheri Station, SV Road (Andheri West)',
#          'Mumbai 400 058',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'categoryCode': 13002,
#          'mapIcon': 'fsq-bakery',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1258653666},
#       'photo': {'id': '50f15210e4b0d13e743dd04a',
#        'createdAt': 1357992464,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/45465192_HUrUFNPVJ9S41UAlfjOmAgaWl2aDt46h8GJ2wqjqzME.jpg',
#        'width': 720,
#        'height': 540,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587e2f964a52095a522e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587d2f964a52009a322e3',
#        'name': "Jogger's Park",
#        'location': {'address': 'Carter Road',
#         'crossStreet': 'Bandra West',
#         'lat': 19.059728381291716,
#         'lng': 72.82205540884804,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.059728381291716,
#           'lng': 72.82205540884804}],
#         'distance': 7215,
#         'postalCode': '400 050',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Carter Road (Bandra West)',
#          'Mumbai 400 050',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'categoryCode': 16032,
#          'mapIcon': 'fsq-landmarks-outdoors',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1258653650},
#       'photo': {'id': '63d8b649dd55917763006606',
#        'createdAt': 1675146825,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/108182_0AGEO_4RPp-xEWDf92k5gdPdDB1gILNqN732IbxAmn8.jpg',
#        'width': 1080,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587d2f964a52009a322e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587cef964a52077a222e3',
#        'name': 'Café Madras',
#        'location': {'address': '38 - II Circle House',
#         'lat': 19.027721224984763,
#         'lng': 72.85519562611115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.027721224984763,
#           'lng': 72.85519562611115}],
#         'distance': 6846,
#         'postalCode': '400019',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['38 - II Circle House',
#          'Mumbai 400019',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'categoryCode': 13034,
#          'mapIcon': 'fsq-coffee',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1258653646},
#       'photo': {'id': '63d6b0308a19030ac92c6974',
#        'createdAt': 1675014192,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/48582462_VnHQwAGENZKFl_x7bJkMwKCLhqjJ5JaSXtqibpKVWw0.jpg',
#        'width': 1920,
#        'height': 1048,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587cef964a52077a222e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3b43c3f964a520f57125e3',
#        'name': 'Candies',
#        'location': {'address': 'Union Park, Pali Hill',
#         'crossStreet': 'St. Andrews Rd.',
#         'lat': 19.061176223187175,
#         'lng': 72.82663421803241,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.061176223187175,
#           'lng': 72.82663421803241}],
#         'distance': 6707,
#         'postalCode': '400050',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Union Park, Pali Hill (St. Andrews Rd.)',
#          'Mumbai 400050',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'categoryCode': 13002,
#          'mapIcon': 'fsq-bakery',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1262175171},
#       'photo': {'id': '51a62b6c498e3e93ad012020',
#        'createdAt': 1369844588,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/11456182_w3H5_-wBpV8VIxWjVu53ZBG41NO20bx5xY8KZ9AKCfw.jpg',
#        'width': 612,
#        'height': 612,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b3b43c3f964a520f57125e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5653381f498e767f964c04c0',
#        'name': 'Inox',
#        'location': {'address': 'R City Mall',
#         'crossStreet': 'LBS Marg Ghatkopar',
#         'lat': 19.099605479954676,
#         'lng': 72.91617311152032,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.099605479954676,
#           'lng': 72.91617311152032}],
#         'distance': 3699,
#         'postalCode': '400086',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['R City Mall (LBS Marg Ghatkopar)',
#          'Mumbai 400086',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'categoryCode': 10024,
#          'mapIcon': 'fsq-arts-entertainment',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1448294431},
#       'photo': {'id': '5d0a58166b628e0030c77cd3',
#        'createdAt': 1560958998,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/518237706_pcvIDPXrY8WtTlj194atyJ3v55jIEGteTDVM9WCSefs.jpg',
#        'width': 1920,
#        'height': 1440,
#        'visibility': 'public'},
#       'referralId': 'e-0-5653381f498e767f964c04c0-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c60336e4b0e2b40dbed48b',
#        'name': 'Pali Bhavan',
#        'location': {'address': '10, Adarsh Nagar, Pali Naka, Near Costa Coffee',
#         'crossStreet': 'Bandra',
#         'lat': 19.06208863111207,
#         'lng': 72.8294592044777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.06208863111207,
#           'lng': 72.8294592044777}],
#         'distance': 6393,
#         'postalCode': '400050',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['10, Adarsh Nagar, Pali Naka, Near Costa Coffee (Bandra)',
#          'Mumbai 400050',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'categoryCode': 13199,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1355154230},
#       'photo': {'id': '524993b711d2657c40f56acb',
#        'createdAt': 1380553655,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1299348_DXSpWK9JQimUN4amt6m2RLFwuc_IO0wQatzJ_zn9bQI.jpg',
#        'width': 960,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-50c60336e4b0e2b40dbed48b-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587d9f964a52021a422e3',
#        'name': 'Ram Ashraya',
#        'location': {'address': 'Near Matunga Central Railway Station, Matunga',
#         'crossStreet': 'Bhandarkar Road, L. Napoo Road',
#         'lat': 19.02809204657728,
#         'lng': 72.85172889717309,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.02809204657728,
#           'lng': 72.85172889717309}],
#         'distance': 6995,
#         'postalCode': '400 019',
#         'cc': 'IN',
#         'neighborhood': 'Matunga East',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Near Matunga Central Railway Station, Matunga (Bhandarkar Road, L. Napoo Road)',
#          'Mumbai 400 019',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegan and Vegetarian Restaurant',
#          'pluralName': 'Vegan and Vegetarian Restaurants',
#          'shortName': 'Vegan and Vegetarian Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'categoryCode': 13377,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1258653657},
#       'photo': {'id': '501d1766e4b03f68ac539161',
#        'createdAt': 1344083814,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/epLTMMk-93b7fVYWPiHRJdsUqMJclXsB8Aqd_Y94SiA.jpg',
#        'width': 543,
#        'height': 540,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587d9f964a52021a422e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4caaa63e2776b60c9f7d450d',
#        'name': 'Carter Road Promenade',
#        'location': {'address': 'Naushad Ali Marg',
#         'crossStreet': 'Bandra (W)',
#         'lat': 19.0666199068567,
#         'lng': 72.82269589828591,
#         'distance': 6929,
#         'postalCode': '400052',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Naushad Ali Marg (Bandra (W))',
#          'Mumbai 400052',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'categoryCode': 16046,
#          'mapIcon': 'fsq-landmarks-outdoors',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1286252094},
#       'photo': {'id': '505dd354e4b0b55bea3c528f',
#        'createdAt': 1348326228,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/13440900_mLU4SzvINTAcl81rJzCaGVnORGgNDTjeCvq7G6svN9U.jpg',
#        'width': 612,
#        'height': 612,
#        'visibility': 'public'},
#       'referralId': 'e-0-4caaa63e2776b60c9f7d450d-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587d2f964a52012a322e3',
#        'name': 'Mahim Dargah',
#        'location': {'address': 'H M A Fakir Street',
#         'crossStreet': 'off Swatantrya Veer Savarkar Marg',
#         'lat': 19.04000844358138,
#         'lng': 72.83941871359193,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.04000844358138,
#           'lng': 72.83941871359193}],
#         'distance': 6788,
#         'postalCode': '400016',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['H M A Fakir Street (off Swatantrya Veer Savarkar Marg)',
#          'Mumbai 400016',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d138941735',
#          'name': 'Mosque',
#          'pluralName': 'Mosques',
#          'shortName': 'Mosque',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_mosque_',
#           'suffix': '.png'},
#          'categoryCode': 12106,
#          'mapIcon': 'fsq-default',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1258653650},
#       'photo': {'id': '5815aa0038fada27f6ef1d85',
#        'createdAt': 1477814784,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/141483601_jbWNZoBIclmn8Lb6axJctBXeDwF-NyG_SBXMSKAcqao.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587d2f964a52012a322e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587e2f964a52094a522e3',
#        'name': 'Hearsch Bakery',
#        'location': {'address': '90/A Hill Road, Opp Cafe Mocha',
#         'crossStreet': 'St. Andrews Rd.',
#         'lat': 19.055119886795794,
#         'lng': 72.82700605766848,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.055119886795794,
#           'lng': 72.82700605766848}],
#         'distance': 6929,
#         'postalCode': '400050',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['90/A Hill Road, Opp Cafe Mocha (St. Andrews Rd.)',
#          'Mumbai 400050',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'categoryCode': 13002,
#          'mapIcon': 'fsq-bakery',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1258653666},
#       'photo': {'id': '51525c8ae4b008e05f44282c',
#        'createdAt': 1364352138,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/37535586_CS3sn9rur0PwOOdz35srUiD2JXdnjV3KWxb2ig3W-vQ.jpg',
#        'width': 720,
#        'height': 960,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587e2f964a52094a522e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587cdf964a52047a222e3',
#        'name': 'Prithvi Cafe',
#        'location': {'address': 'Juhu Church Road',
#         'lat': 19.106153210060764,
#         'lng': 72.82586610755753,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.106153210060764,
#           'lng': 72.82586610755753}],
#         'distance': 6952,
#         'postalCode': '400 049',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Juhu Church Road',
#          'Mumbai 400 049',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'categoryCode': 13034,
#          'mapIcon': 'fsq-coffee',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '34912879'},
#        'createdAt': 1258653645},
#       'photo': {'id': '5226e02711d222413bc2b121',
#        'createdAt': 1378279463,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/9495111_QxxTP3jbG-vX-eaYsDrI-sYMsnz8Yj68_UJ4EZc9kTI.jpg',
#        'width': 612,
#        'height': 612,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587cdf964a52047a222e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587d2f964a520f3a222e3',
#        'name': 'Mount Mary Church (The Basilica of Our Lady of the Mount)',
#        'location': {'address': 'Mount Mary Road, Bandra',
#         'crossStreet': 'Cane Road',
#         'lat': 19.04658977257696,
#         'lng': 72.82221363883296,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.04658977257696,
#           'lng': 72.82221363883296}],
#         'distance': 7816,
#         'postalCode': '400 050',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Mount Mary Road, Bandra (Cane Road)',
#          'Mumbai 400 050',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'categoryCode': 12101,
#          'mapIcon': 'fsq-default',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1258653650},
#       'photo': {'id': '4f6873d8003938727b392f69',
#        'createdAt': 1332245464,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/PEtlRITHQgg4wlazRrGpd_wspEft-EIk6o3H9WJnfTo.jpg',
#        'width': 800,
#        'height': 534,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587d2f964a520f3a222e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc1d37c3d7fa1cd0de39a5f',
#        'name': "Joey's Pizza",
#        'location': {'address': '6 & 7, Upvan Bldg, Behind Indian Oil Colony, D N Nagar, New Lic Colony Rd, Andheri (W)',
#         'crossStreet': 'Andheri',
#         'lat': 19.126762155150107,
#         'lng': 72.83000121236746,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.126762155150107,
#           'lng': 72.83000121236746}],
#         'distance': 7796,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['6 & 7, Upvan Bldg, Behind Indian Oil Colony, D N Nagar, New Lic Colony Rd, Andheri (W) (Andheri)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizzeria',
#          'pluralName': 'Pizzerias',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'categoryCode': 13064,
#          'mapIcon': 'fsq-pizza',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1287771004},
#       'photo': {'id': '512faa2ae4b00b1144d83fcc',
#        'createdAt': 1362078250,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/39193531_ZpmpTAeUv9NXQi3bRBa_zlPTo_WktKYPb6Ccq8QN6ik.jpg',
#        'width': 960,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4cc1d37c3d7fa1cd0de39a5f-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba62853f964a520dd3739e3',
#        'name': 'Bandstand Promenade',
#        'location': {'crossStreet': 'Byramji Jeejobhoy Rd',
#         'lat': 19.046946970470685,
#         'lng': 72.81991481781006,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.046946970470685,
#           'lng': 72.81991481781006}],
#         'distance': 8008,
#         'postalCode': '400050',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Bandra West (Byramji Jeejobhoy Rd)',
#          'Mumbai 400050',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'categoryCode': 16046,
#          'mapIcon': 'fsq-landmarks-outdoors',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1269180499},
#       'photo': {'id': '63d271f1a0c4ea72fcb83bc9',
#        'createdAt': 1674736113,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/13186316_ZXdRuuXILbVA2WBUaVUZHJ6GJWXCEFf7jFluyCERA3o.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4ba62853f964a520dd3739e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56345dce498e87c16cbd1843',
#        'name': 'Khar Social',
#        'location': {'address': 'Behind Ramee',
#         'crossStreet': 'SV Road',
#         'lat': 19.068243423955007,
#         'lng': 72.83802654231332,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.068243423955007,
#           'lng': 72.83802654231332}],
#         'distance': 5324,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Behind Ramee (SV Road)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'categoryCode': 13003,
#          'mapIcon': 'fsq-bar',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1446272462},
#       'photo': {'id': '5d7370d587f7b80008b83b85',
#        'createdAt': 1567846613,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/152644219_sgKzhcppdbpibpT_2CDz9V1c2h0hbcReeN02oH5nldk.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-56345dce498e87c16cbd1843-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5dc6e6f964a520166b29e3',
#        'name': 'Ming Yang',
#        'location': {'address': 'Taj Lands End',
#         'crossStreet': 'Bandra Lands End',
#         'lat': 19.04358247268375,
#         'lng': 72.81919874442222,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.04358247268375,
#           'lng': 72.81919874442222}],
#         'distance': 8259,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Taj Lands End (Bandra Lands End)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'categoryCode': 13099,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1264436966},
#       'photo': {'id': '654752d34fddb47485b39128',
#        'createdAt': 1699173075,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/8704432_VC6TYPGM0cUA0AyOfOULbKls3ReZkzYi52R0err5E6U.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b5dc6e6f964a520166b29e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfa2c3b45dd2b6764bdea70',
#        'name': 'Meluha, The Fern',
#        'location': {'address': 'Central Avenue, Hiranandani Gardens, Powai, Powai',
#         'lat': 19.11772547741495,
#         'lng': 72.91111433582635,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.11772547741495,
#           'lng': 72.91111433582635}],
#         'distance': 4777,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Central Avenue, Hiranandani Gardens, Powai, Powai',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'categoryCode': 19014,
#          'mapIcon': 'fsq-lodging',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1308240955},
#       'photo': {'id': '506da5c9e4b08b87bb2810e7',
#        'createdAt': 1349363145,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/4217816_7EmDwJF1SEcDq-J35RkPLQx2x7Kx8bHz4sqboSa41_0.jpg',
#        'width': 537,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4dfa2c3b45dd2b6764bdea70-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da44e999935a093003cda6f',
#        'name': 'Neelam Foodland',
#        'location': {'address': 'Tanna Kutir Apartment, Danda Road, Khar West',
#         'lat': 19.07366345188169,
#         'lng': 72.83004736158074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.07366345188169,
#           'lng': 72.83004736158074}],
#         'distance': 6017,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Tanna Kutir Apartment, Danda Road, Khar West',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'categoryCode': 17069,
#          'mapIcon': 'fsq-default',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1302613657},
#       'photo': {'id': '4fd35553e4b0052fbb774b59',
#        'createdAt': 1339250003,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/oEu_-LjwLKBXgzUUhi95zTPeVGavzXd9f6N-nQQIm0M.jpg',
#        'width': 612,
#        'height': 612,
#        'visibility': 'public'},
#       'referralId': 'e-0-4da44e999935a093003cda6f-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fc3615498e141bd45da525',
#        'name': "Jaffer Bhai's Delhi Darbar",
#        'location': {'address': 'Jogeshwari West',
#         'lat': 19.137714056593047,
#         'lng': 72.84590930883026,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.137714056593047,
#           'lng': 72.84590930883026}],
#         'distance': 7575,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Jogeshwari West',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff4',
#          'name': 'Mughlai Restaurant',
#          'pluralName': 'Mughlai Restaurants',
#          'shortName': 'Mughlai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'categoryCode': 13216,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1442592277},
#       'photo': {'id': '5a6b69021cf2e1734c5b6542',
#        'createdAt': 1516988674,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/20356139_I_43O8FWF6TABY_SnKC8qmky1tBtMLiFDEuu693fBaI.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
# ...
#         'lng': 72.82251196171583,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 18.928425922468104,
#           'lng': 72.82251196171583}],
#         'distance': 18335,
#         'postalCode': '400021',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Ground Floor, Express Towers (Nariman Point)',
#          'Mumbai 400021',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'categoryCode': 13049,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '50517076'},
#        'createdAt': 1359732761},
#       'photo': {'id': '5dea7ee193de190008e7f686',
#        'createdAt': 1575648993,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1589670_wd-fUp1NT8mhqFW9c64LfywTZ-soc8i4Qn1Ntq0grjU.jpg',
#        'width': 1920,
#        'height': 1440,
#        'visibility': 'public'},
#       'referralId': 'e-0-510be019e4b04c8c9a348a1a-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d691357342b8cfa3170c32c',
#        'name': 'K Rustoms Ice Cream',
#        'location': {'address': 'Veer Nariman Rd',
#         'lat': 18.933478146064274,
#         'lng': 72.824995132785,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 18.933478146064274,
#           'lng': 72.824995132785}],
#         'distance': 17716,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Veer Nariman Rd',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Parlor',
#          'pluralName': 'Ice Cream Parlors',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'categoryCode': 13046,
#          'mapIcon': 'fsq-dessert',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1298731863},
#       'photo': {'id': '51850b01498e26ededfd63f4',
#        'createdAt': 1367673601,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/4707318_k8q5oWWdGtJEKyILThcvbgheo2_DyyH_lHt82Sjz_7c.jpg',
#        'width': 1434,
#        'height': 1918,
#        'visibility': 'public'},
#       'referralId': 'e-0-4d691357342b8cfa3170c32c-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd194c801eaf04d9122bf5d',
#        'name': 'Soam',
#        'location': {'address': '3 Sadguru Sadan, opp. Babulnath Temple, Girgaum Chowpatty,',
#         'lat': 18.957492031614574,
#         'lng': 72.80888354503129,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 18.957492031614574,
#           'lng': 72.80888354503129}],
#         'distance': 16054,
#         'postalCode': '400007',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['3 Sadguru Sadan, opp. Babulnath Temple, Girgaum Chowpatty,',
#          'Mumbai 400007',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'categoryCode': 13199,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1288803528},
#       'photo': {'id': '50969ba7e4b00a7cdeb7adf7',
#        'createdAt': 1352047527,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/25323088_aFqg6VKUKmDMyKfeDQKVRCK7_4rDF0aJ5s88Y8g8mrQ.jpg',
#        'width': 540,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4cd194c801eaf04d9122bf5d-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d2606a895e8f04da12e3f4d',
#        'name': "Natural's",
#        'location': {'address': 'Mahavir Nagar',
#         'crossStreet': 'Kandivali',
#         'lat': 19.20992498008812,
#         'lng': 72.83988846875732,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.20992498008812,
#           'lng': 72.83988846875732}],
#         'distance': 15109,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Mahavir Nagar (Kandivali)',
#          'Mumbai',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'categoryCode': 13040,
#          'mapIcon': 'fsq-dessert',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1294337704},
#       'photo': {'id': '4ef4783ab8f77e0f97ec4192',
#        'createdAt': 1324644410,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/SCFRMLX01OLQPSV5YYBDOWSM0LJGXOQLHUXCUATMMKSZNXI3.jpg',
#        'width': 720,
#        'height': 405,
#        'visibility': 'public'},
#       'referralId': 'e-0-4d2606a895e8f04da12e3f4d-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e03166fb3ad7a4de179a603',
#        'name': 'National Centre for the Performing Arts (NCPA)',
#        'location': {'address': 'Nariman Point',
#         'crossStreet': 'NCPA Marg',
#         'lat': 18.92563130239702,
#         'lng': 72.81986117362976,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 18.92563130239702,
#           'lng': 72.81986117362976}],
#         'distance': 18728,
#         'postalCode': '400021',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Nariman Point (NCPA Marg)',
#          'Mumbai 400021',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'categoryCode': 10035,
#          'mapIcon': 'fsq-arts-entertainment',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1308825199},
#       'photo': {'id': '514f015ee4b08c23d97e85b9',
#        'createdAt': 1364132190,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/9662739_r5012pF6LgL-ZI0KCJ2NmB59Vv-CtEo0NU9AL-K1u2g.jpg',
#        'width': 720,
#        'height': 960,
#        'visibility': 'public'},
#       'referralId': 'e-0-4e03166fb3ad7a4de179a603-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52f38fb511d2024e73897bd1',
#        'name': 'Starbucks',
#        'location': {'address': 'B-2, V Souk, Mahavir Nagar, Kandivali West',
#         'crossStreet': 'Mahavir Nagar, Kandivali West,',
#         'lat': 19.21292730822335,
#         'lng': 72.8422918067928,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.21292730822335,
#           'lng': 72.8422918067928}],
#         'distance': 15347,
#         'postalCode': '400067',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['B-2, V Souk, Mahavir Nagar, Kandivali West (Mahavir Nagar, Kandivali West,)',
#          'Mumbai 400067',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'categoryCode': 13035,
#          'mapIcon': 'fsq-coffee',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1391693749},
#       'photo': {'id': '5a081a2c9deb7d67451ffd65',
#        'createdAt': 1510480428,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/61490415_80YiYuHgraFXmmbfOtEaFBOJgmA4H7m_7Ga6eAKHE-8.jpg',
#        'width': 1080,
#        'height': 1440,
#        'visibility': 'public'},
#       'referralId': 'e-0-52f38fb511d2024e73897bd1-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3728eef964a520b83f25e3',
#        'name': 'Sarvi',
#        'location': {'address': 'Nagpada',
#         'lat': 18.96685250452282,
#         'lng': 72.82922116407411,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 18.96685250452282,
#           'lng': 72.82922116407411}],
#         'distance': 14127,
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Nagpada', 'Mumbai', 'Mahārāshtra', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'categoryCode': 13309,
#          'mapIcon': 'fsq-dining',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1261906158},
#       'photo': {'id': '50b0dfcde4b00a661cd568b0',
#        'createdAt': 1353768909,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/24956616_ogokTuf1Bvpz16U5A0IMASsqunVW9UDpq2WqlSc8nq4.jpg',
#        'width': 537,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b3728eef964a520b83f25e3-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50839d9de4b0073ffbb281cc',
#        'name': 'CreamChills',
#        'location': {'address': 'Opp. Gautam Arcade, Next to ICICI Bank,',
#         'crossStreet': 'Harishchandra Raut Marg, Kopri',
#         'lat': 19.182281566771128,
#         'lng': 72.97608748264356,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.182281566771128,
#           'lng': 72.97608748264356}],
#         'distance': 14635,
#         'postalCode': '400603',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Opp. Gautam Arcade, Next to ICICI Bank, (Harishchandra Raut Marg, Kopri)',
#          'Thane East 400603',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'categoryCode': 13040,
#          'mapIcon': 'fsq-dessert',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1350802845},
#       'photo': {'id': '5634f2bd498ec53d2d389a02',
#        'createdAt': 1446310589,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/31557714_q_nldHRgzow1gtTd3FL_TkZUbOyC-krZC7OInySFXvw.jpg',
#        'width': 540,
#        'height': 960,
#        'visibility': 'public'},
#       'referralId': 'e-0-50839d9de4b0073ffbb281cc-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9c68ddf964a5209a6636e3',
#        'name': 'Café Mondegar',
#        'location': {'address': 'Metro House, 5-A Shahid Bhagat Singh Road',
#         'crossStreet': 'Near Regal Cinema',
#         'lat': 18.924219037574055,
#         'lng': 72.83210608191361,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 18.924219037574055,
#           'lng': 72.83210608191361}],
#         'distance': 18432,
#         'postalCode': '400039',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Metro House, 5-A Shahid Bhagat Singh Road (Near Regal Cinema)',
#          'Mumbai 400039',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'categoryCode': 13034,
#          'mapIcon': 'fsq-coffee',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1268541661},
#       'photo': {'id': '4fb64f63e4b033224657eda6',
#        'createdAt': 1337347939,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/i19cAiy0YqJp1DC2V-7khrp2iyXSnFzeNt_4JCSzHiQ.jpg',
#        'width': 540,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b9c68ddf964a5209a6636e3-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0587cef964a5207ba222e3',
#        'name': 'Woodside Inn',
#        'location': {'address': 'Indian Mercantile Mansion, Wodehouse Rd',
#         'crossStreet': 'opposite Regal Cinema',
#         'lat': 18.92475092153973,
#         'lng': 72.8319296651825,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 18.92475092153973,
#           'lng': 72.8319296651825}],
#         'distance': 18382,
#         'postalCode': '400 039',
#         'cc': 'IN',
#         'city': 'Mumbai',
#         'state': 'Mahārāshtra',
#         'country': 'India',
#         'formattedAddress': ['Indian Mercantile Mansion, Wodehouse Rd (opposite Regal Cinema)',
#          'Mumbai 400 039',
#          'Mahārāshtra',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'categoryCode': 13018,
#          'mapIcon': 'fsq-bar',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1258653646},
#       'photo': {'id': '51b2197a498ebf0264c73447',
#        'createdAt': 1370626426,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1447425_TCzSO3gIytbZ385sL64QBpyd1Rm4tx9TBG_hJkuzaoc.jpg',
#        'width': 612,
#        'height': 612,
#        'visibility': 'public'},
#       'referralId': 'e-0-4b0587cef964a5207ba222e3-99'}]}]}}

# %%
df1 = pd.json_normalize(data['response']['groups'][0]['items'])

# %%
df1.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-54a3a602498e6d5ac992f927-0              0
# 1  e-0-5a21b1cea4236243c9628ad2-1              0
# 2  e-0-546f25c5498e2d4d056ad6eb-2              0
# 3  e-0-54a3b679498ef4dcbbf3ce69-3              0
# 4  e-0-4b0587d8f964a52008a422e3-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id                venue.name  \
# 0  54a3a602498e6d5ac992f927  JW Marriott Mumbai Sahar
# 1  5a21b1cea4236243c9628ad2                   Hitchki
# 2  546f25c5498e2d4d056ad6eb                 Starbucks
# 3  54a3b679498ef4dcbbf3ce69                  J W Cafe
# 4  4b0587d8f964a52008a422e3                Guru Kripa
#
#                               venue.location.address  venue.location.lat  \
# 0  IA Project Road, Chhatrapati Shivaji Internati...           19.102502
# 1                                               FIFC           19.069730
# 2                                        The Capital           19.063457
# 3                          JW Marriott Mumbai Sahara           19.103212
# 4             Guru Kripa Building, Near SIES College           19.042955
#
#    venue.location.lng                      venue.location.labeledLatLngs  \
# 0           72.878236  [{'label': 'display', 'lat': 19.102502, 'lng':...
# 1           72.869761  [{'label': 'display', 'lat': 19.06972997280986...
# 2           72.861576  [{'label': 'display', 'lat': 19.06345693697131...
# 3           72.877504  [{'label': 'display', 'lat': 19.10321177850576...
# 4           72.861796  [{'label': 'display', 'lat': 19.04295461255925...
#
#    venue.location.distance  ... venue.createdAt                  photo.id  \
# 0                     2490  ...      1420011010  65310334cc33ec55491c5eea
# 1                     2210  ...      1512157646  610a697d06450766fb84dee6
# 2                     3318  ...      1416570309  5fc63feb5ae69d3de3909947
# 3                     2592  ...      1420015225  5d79ced02b61ba000733f458
# 4                     5030  ...      1258653656  504c914fe4b0369116e22552
#
#   photo.createdAt                          photo.prefix  \
# 0    1.697711e+09  https://fastly.4sqi.net/img/general/
# 1    1.628072e+09  https://fastly.4sqi.net/img/general/
# 2    1.606828e+09  https://fastly.4sqi.net/img/general/
# 3    1.568264e+09  https://fastly.4sqi.net/img/general/
# 4    1.347195e+09  https://fastly.4sqi.net/img/general/
#
#                                         photo.suffix photo.width photo.height  \
# 0  /5665606_w8AruerI5qcxoIgU_hno8O_vdobbF081eborF...      1440.0       1920.0
# 1  /4048110_KP9wINx95ITkmPAVbz6wCLkL0xT0XE0ZZDKsu...      1789.0       1440.0
# 2  /3775888_jccbgErinMgtHlsgCFQdge-UjSPd8Abnm-yFX...      1440.0       1920.0
# 3  /63477693_6gdQi6nZA_YkD2YRQzraTM6AoxU4nFIJlD_F...      1440.0       1920.0
# 4   /LLJ_16ESwON753MoDxc-tONaoeWqWew0PfxQreb8lTM.jpg       720.0        406.0
#
#    photo.visibility venue.location.crossStreet venue.location.neighborhood
# 0            public                        NaN                         NaN
# 1            public  Bandra Kurla Complex, BKC                         NaN
# 2            public                        NaN                         NaN
# 3            public            IA Project Road                     Airport
# 4            public                   Rd No 24                         NaN
#
# [5 rows x 30 columns]

# %%
df1.shape
# Out:
# (100, 30)

# %% [markdown]
# ### Try to find the number of restaurants and other famous places such as park,museums etc.

# %%
num_restaurants = []
num_fplaces = []
for lat,lng in zip(df1['venue.location.lat'],df1['venue.location.lng']):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
      CLIENT_ID, 
      CLIENT_SECRET, 
      VERSION, 
      lat,lng,
      1000, 
      100)
    r = requests.get(url).json()
    df_final = pd.json_normalize(r['response']['groups'][0]['items'])
    df=df_final['venue.categories']

    parks = []
    for i in range(0,df.size):
      parks.append(df[i][0]['icon']['prefix'].find('food'))
    rem=0
    for i in parks:
      if i>1:
        rem+=1
    num_restaurants.append(rem)
    num_fplaces.append(len(parks)-rem)

# %%
df_final["Restaurants"] = pd.Series(num_restaurants)
df_final["Others"] = pd.Series(num_fplaces)

# %%
df_final.columns
df_final["venue.location.address"]
# Out:
# 0             Metro House, 5-A Shahid Bhagat Singh Road
# 1               Indian Mercantile Mansion, Wodehouse Rd
# 2                               159-161 M.G. Road, Fort
# 3     Kalash Peshi Building, CS Maharishi Marg, Apol...
# 4                                         Dhanraj Mahal
#                             ...
# 95                           25, Off Arthur Bunder Road
# 96                                      17, Oliver Road
# 97                                         Nanabhai Ln.
# 98                     Eros Cinema Building, Churchgate
# 99                             J. Tata Road, Churchgate
# Name: venue.location.address, Length: 100, dtype: object

# %%
df_final.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4b9c68ddf964a5209a6636e3-0              0
# 1  e-0-4b0587cef964a5207ba222e3-1              0
# 2  e-0-4b0587d1f964a520cfa222e3-2              0
# 3  e-0-4d31c8065c2db60cbb6ebb6c-3              0
# 4  e-0-50caded2e4b06f07c9b15053-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id  \
# 0  4b9c68ddf964a5209a6636e3
# 1  4b0587cef964a5207ba222e3
# 2  4b0587d1f964a520cfa222e3
# 3  4d31c8065c2db60cbb6ebb6c
# 4  50caded2e4b06f07c9b15053
#
#                                           venue.name  \
# 0                                      Café Mondegar
# 1                                       Woodside Inn
# 2  Chhatrapati Shivaji Maharaj Vastu Sangrahalaya...
# 3                                          The Table
# 4                                PizzaExpress Colaba
#
#                               venue.location.address  \
# 0          Metro House, 5-A Shahid Bhagat Singh Road
# 1            Indian Mercantile Mansion, Wodehouse Rd
# 2                            159-161 M.G. Road, Fort
# 3  Kalash Peshi Building, CS Maharishi Marg, Apol...
# 4                                      Dhanraj Mahal
#
#     venue.location.crossStreet  venue.location.lat  venue.location.lng  \
# 0            Near Regal Cinema           18.924219           72.832106
# 1        opposite Regal Cinema           18.924751           72.831930
# 2                          NaN           18.926864           72.832559
# 3  Behind Regal Cinema, Colaba           18.924099           72.833097
# 4                       Colaba           18.923899           72.833452
#
#                        venue.location.labeledLatLngs  ...  photo.createdAt  \
# 0  [{'label': 'display', 'lat': 18.92421903757405...  ...     1.337348e+09
# 1  [{'label': 'display', 'lat': 18.92475092153973...  ...     1.370626e+09
# 2  [{'label': 'display', 'lat': 18.92686438179064...  ...     1.699961e+09
# 3  [{'label': 'display', 'lat': 18.924099, 'lng':...  ...     1.374056e+09
# 4  [{'label': 'display', 'lat': 18.92389908404944...  ...     1.359047e+09
#
#                            photo.prefix  \
# 0  https://fastly.4sqi.net/img/general/
# 1  https://fastly.4sqi.net/img/general/
# 2  https://fastly.4sqi.net/img/general/
# 3  https://fastly.4sqi.net/img/general/
# 4  https://fastly.4sqi.net/img/general/
#
#                                         photo.suffix photo.width photo.height  \
# 0   /i19cAiy0YqJp1DC2V-7khrp2iyXSnFzeNt_4JCSzHiQ.jpg       540.0        720.0
# 1  /1447425_TCzSO3gIytbZ385sL64QBpyd1Rm4tx9TBG_hJ...       612.0        612.0
# 2  /188855391_iyYMBFsI-1xuhlgBJE8vDhcHgY14IOv70GV...      1440.0       1920.0
# 3  /13243159_DKu2218jt9OZGhEwE479DFNRgXU6oQ51JTNX...       612.0        612.0
# 4  /41615423_BgkpY_FHy6Bgo-9zvgKOuxkXUa8jmbYPyNW4...       720.0        540.0
#
#   photo.visibility venue.venuePage.id venue.location.neighborhood  \
# 0           public                NaN                         NaN
# 1           public                NaN                         NaN
# 2           public                NaN                         NaN
# 3           public           64524206                         NaN
# 4           public                NaN                         NaN
#
#    Restaurants Others
# 0           65     35
# 1           30     11
# 2           40     11
# 3           67     33
# 4           21      7
#
# [5 rows x 32 columns]

# %%
df_final = df_final[['venue.location.lat','venue.location.lng','Restaurants', 'Others', "venue.location.address"]]
# df_final["venue.location.address"]

# %%
df_final
# Out:
#     venue.location.lat  venue.location.lng  Restaurants  Others  \
# 0            18.924219           72.832106           65      35
# 1            18.924751           72.831930           30      11
# 2            18.926864           72.832559           40      11
# 3            18.924099           72.833097           67      33
# 4            18.923899           72.833452           21       7
# ..                 ...                 ...          ...     ...
# 95           18.917069           72.830009           25       9
# 96           18.919641           72.830861           18       7
# 97           18.932908           72.832462           14       7
# 98           18.932549           72.827671           61      39
# 99           18.932057           72.827150           62      38
#
#                                venue.location.address
# 0           Metro House, 5-A Shahid Bhagat Singh Road
# 1             Indian Mercantile Mansion, Wodehouse Rd
# 2                             159-161 M.G. Road, Fort
# 3   Kalash Peshi Building, CS Maharishi Marg, Apol...
# 4                                       Dhanraj Mahal
# ..                                                ...
# 95                         25, Off Arthur Bunder Road
# 96                                    17, Oliver Road
# 97                                       Nanabhai Ln.
# 98                   Eros Cinema Building, Churchgate
# 99                           J. Tata Road, Churchgate
#
# [100 rows x 5 columns]

# %%
df_final = df_final.dropna()

# %%
df_final = df_final.rename(columns={'venue.location.lat': 'Latitude', 'venue.location.lng': 'Longitude'})
df_final.head()
# Out:
#     Latitude  Longitude  Restaurants  Others  \
# 0  18.924219  72.832106           65      35
# 1  18.924751  72.831930           30      11
# 2  18.926864  72.832559           40      11
# 3  18.924099  72.833097           67      33
# 4  18.923899  72.833452           21       7
#
#                               venue.location.address
# 0          Metro House, 5-A Shahid Bhagat Singh Road
# 1            Indian Mercantile Mansion, Wodehouse Rd
# 2                            159-161 M.G. Road, Fort
# 3  Kalash Peshi Building, CS Maharishi Marg, Apol...
# 4                                      Dhanraj Mahal

# %%
final_data = df_final.copy()
final_data= final_data.drop(['venue.location.address'],axis =1)
# X = final_data.values
# X[:5]
final_data.head()
# Out:
#     Latitude  Longitude  Restaurants  Others
# 0  18.924219  72.832106           65      35
# 1  18.924751  72.831930           30      11
# 2  18.926864  72.832559           40      11
# 3  18.924099  72.833097           67      33
# 4  18.923899  72.833452           21       7

# %% [markdown]
# ### Applying Kmeans on the final data

# %%
sse = []
k_max = 10
for i in range(1,k_max+1):
  kmeans =KMeans(n_clusters=i,n_init = 1, init = 'k-means++',random_state=0)
  kmeans.fit(final_data)
  sse.append(kmeans.inertia_)
plt.plot(range(1,11),sse)
plt.show()

# %% [markdown]
# From above graph optimal value for K = 3

# %%
kmeans  = KMeans(n_clusters= 3, init='k-means++',random_state=0)
final_data['Cluster']=kmeans.fit_predict(final_data)
# Out:
# E:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
final_data.head()
# Out:
#     Latitude  Longitude  Restaurants  Others  Cluster
# 0  18.924219  72.832106           65      35        0
# 1  18.924751  72.831930           30      11        1
# 2  18.926864  72.832559           40      11        2
# 3  18.924099  72.833097           67      33        0
# 4  18.923899  72.833452           21       7        1

# %%
closest = kmeans.cluster_centers_
final_data["centroids"] = 0
for i in range(len(closest)):
    final_data["centroids"].iloc[i] = 1
# Out:
# C:\Users\pmeen\AppData\Local\Temp\ipykernel_18888\71522798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data["centroids"].iloc[i] = 1

# %%
final_data[final_data['centroids']==1]
# Out:
#     Latitude  Longitude  Restaurants  Others  Cluster  centroids
# 0  18.924219  72.832106           65      35        0          1
# 1  18.924751  72.831930           30      11        1          1
# 2  18.926864  72.832559           40      11        2          1

# %%
final_data['venue.location.address'] = df_final['venue.location.address']
final_data.head()
# Out:
#     Latitude  Longitude  Restaurants  Others  Cluster  centroids  \
# 0  18.924219  72.832106           65      35        0          1
# 1  18.924751  72.831930           30      11        1          1
# 2  18.926864  72.832559           40      11        2          1
# 3  18.924099  72.833097           67      33        0          0
# 4  18.923899  72.833452           21       7        1          0
#
#                               venue.location.address
# 0          Metro House, 5-A Shahid Bhagat Singh Road
# 1            Indian Mercantile Mansion, Wodehouse Rd
# 2                            159-161 M.G. Road, Fort
# 3  Kalash Peshi Building, CS Maharishi Marg, Apol...
# 4                                      Dhanraj Mahal

# %%
plt.scatter(final_data["Latitude"],final_data["Longitude"], c=kmeans.labels_.astype(float))
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker = "d", s=50, c='red')
plt.show()

# %% [markdown]
# ### Plot the results on map

# %%
m = folium.Map(location=[12, -122.6750])

# %%
city = "Mumbai"
## get location
locator = geopy.geocoders.Nominatim(user_agent="Pradeep")
location = locator.geocode(city)
print(location)

## keep latitude and longitude only
location = [location.latitude, location.longitude]
print("[lat, lng]:", location)
# Out:
# Mumbai, Mumbai Suburban, Maharashtra, India
# [lat, lng]: [19.08157715, 72.88662753964906]

# %%
x, y = "Latitude", "Longitude"
color = "Cluster"
size = "Restaurants"
popup = "venue.location.address"
marker = "centroids"
data = final_data.copy()
## create color column
lst_elements = sorted(list(final_data[color].unique()))
lst_colors = ['#%06X' % np.random.randint(0, 0xFFFFFF) for i in 
              range(len(lst_elements))]
data["color"] = data[color].apply(lambda x: 
                lst_colors[lst_elements.index(x)])
## create size column (scaled)
scaler = preprocessing.MinMaxScaler(feature_range=(3,15))
data["size"] = scaler.fit_transform(
               data[size].values.reshape(-1,1)).reshape(-1)
## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=11)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]], 
           color=row["color"], fill=True,popup=row[popup],
           radius=row["size"]).add_to(map_), axis=1)
## add html legend
legend_html = """ """+color+""":"""
for i in lst_elements:
     legend_html = legend_html+""" 
      """+str(i)+""""""
legend_html = legend_html+""""""
map_.get_root().html.add_child(folium.Element(legend_html))
## add centroids marker
lst_elements = sorted(list(final_data[marker].unique()))
data[data[marker]==1].apply(lambda row: 
           folium.Marker(location=[row[x],row[y]], 
           draggable=False,  popup=row[popup] ,       
           icon=folium.Icon(color="black")).add_to(map_), axis=1)
## plot the map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6 popup = "venue.location.address"
#       7 marker = "centroids"
# ----> 8 data = final_data.copy()
#       9 ## create color column
#      10 lst_elements = sorted(list(final_data[color].unique()))
#
# NameError: name 'final_data' is not defined
